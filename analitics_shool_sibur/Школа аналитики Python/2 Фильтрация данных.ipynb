# %% [markdown]
# # Фильтрация данных в pandas
#
# Одной из самых популярных функций в Excel являются фильтры, которые позволяют в пару нажатий убрать из рассмотрения ненужные данные. В этом уроке мы научимся производить фильтрацию табличных данных в Python:

# %% [markdown]
# ## Получение данных
#
# Для начала импортируем библиотеку `pandas` и откроем первый лист файла `Superstore.xls`, открытую таблицу сохраним как `orders`:

# %%
import pandas as pd
# Вы уже умеете это делать, попробуйте сами или скопируйте из предыдущего урока

# %% [markdown]
# Получать данные из таблицы мы научились в предыдущем уроке, перейдем сразу к их сравнению.

# %% [markdown]
# ## Фильтры
#
# Данные, полученные через методами `loc` и `iloc` могут быть использованы в операциях сравнения, при этом сравнивать можно сравнивать целые столбцы и строки. Для фильтрации данных условие должно быть записано в левой части оператора `loc`, как показано в примере ниже:

# %%
orders = pd.read_excel('Superstore.xls', sheet_name = 'Orders')

# %%
orders.loc[orders.loc[:, 'Region'] == 'South', :];
orders[orders['Region']=='South'].head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...     42420.0   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %% [markdown]
# В Python можно использовать следующие операторы сравнения: равно (`==`), не равно (`!=`), больше (`>`), больше или равно (`>=`), меньше (`<`), меньше или равно (`<=`).

# %% [markdown]
# Условия можно комбинировать с помощью операторов `&` – логическое И, `|` – логическое ИЛИ и круглых скобок:

# %%
# Просмотрим офисные принадлежности, проданные в Штате Флорида
orders[(orders['Category']=='Office Supplies') and (orders['State']=='Florida')]; # для пандаса надо "&"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-07124c77db2c> in <module>
#       1 # Просмотрим офисные принадлежности, проданные в Штате Флорида
# ----> 2 orders[(orders['Category']=='Office Supplies') and (orders['State']=='Florida')];
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Продукты, проданные со скидкой больше 60 процентов или проданные дешевле себестоимости
1 and 1
# Out:
# 1

# %% [markdown]
# Мы очень советуем не использовать сложные условия внутри функции `loc`, а создавать для этого отдельные переменные:

# %%
map_1 = orders.loc[:, 'State'] == 'Florida'
map_2 = orders.loc[:, 'State'] == 'Texas'
map_3 = orders.loc[:, 'Discount'] > 0
filter_ = (map_1 | map_2) & map_3
orders.loc[filter_, :]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 14        15  US-2016-118983 2016-11-22 2016-11-26  Standard Class
# 15        16  US-2016-118983 2016-11-22 2016-11-26  Standard Class
# 34        35  CA-2018-107727 2018-10-19 2018-10-23    Second Class
# ...      ...             ...        ...        ...             ...
# 9920    9921  CA-2017-149272 2017-03-15 2017-03-19  Standard Class
# 9961    9962  CA-2016-168088 2016-03-19 2016-03-22     First Class
# 9962    9963  CA-2016-168088 2016-03-19 2016-03-22     First Class
# 9972    9973  CA-2017-130225 2017-09-11 2017-09-17  Standard Class
# 9989    9990  CA-2015-110422 2015-01-21 2015-01-23    Second Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# 4       SO-20335    Sean O'Donnell     Consumer  United States
# 14      HP-14815     Harold Pawlan  Home Office  United States
# 15      HP-14815     Harold Pawlan  Home Office  United States
# 34      MA-17560      Matt Abelman  Home Office  United States
# ...          ...               ...          ...            ...
# 9920    MY-18295   Muhammed Yedwab    Corporate  United States
# 9961    CM-12655  Corinna Mitchell  Home Office  United States
# 9962    CM-12655  Corinna Mitchell  Home Office  United States
# 9972    RC-19960        Ryan Crowe     Consumer  United States
# 9989    TB-21400  Tom Boeckenhauer     Consumer  United States
#
#                  City  ... Postal Code   Region       Product ID  \
# 3     Fort Lauderdale  ...     33311.0    South  FUR-TA-10000577
# 4     Fort Lauderdale  ...     33311.0    South  OFF-ST-10000760
# 14         Fort Worth  ...     76106.0  Central  OFF-AP-10002311
# 15         Fort Worth  ...     76106.0  Central  OFF-BI-10000756
# 34            Houston  ...     77095.0  Central  OFF-PA-10000249
# ...               ...  ...         ...      ...              ...
# 9920            Bryan  ...     77803.0  Central  OFF-BI-10004233
# 9961          Houston  ...     77041.0  Central  OFF-PA-10000675
# 9962          Houston  ...     77041.0  Central  FUR-BO-10004218
# 9972          Houston  ...     77041.0  Central  OFF-EN-10000056
# 9989            Miami  ...     33180.0    South  FUR-FU-10001889
#
#              Category Sub-Category  \
# 3           Furniture       Tables
# 4     Office Supplies      Storage
# 14    Office Supplies   Appliances
# 15    Office Supplies      Binders
# 34    Office Supplies        Paper
# ...               ...          ...
# 9920  Office Supplies      Binders
# 9961  Office Supplies        Paper
# 9962        Furniture    Bookcases
# 9972  Office Supplies    Envelopes
# 9989        Furniture  Furnishings
#
#                                            Product Name     Sales  Quantity  \
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# 14    Holmes Replacement Filter for HEPA Air Cleaner...   68.8100         5
# 15     Storex DuraTech Recycled Plastic Frosted Binders    2.5440         3
# 34                                    Easy-staple paper   29.4720         3
# ...                                                 ...       ...       ...
# 9920  GBC Pre-Punched Binding Paper, Plastic, White,...   22.3860         7
# 9961                                         Xerox 1919   65.5840         2
# 9962  Bush Heritage Pine Collection 5-Shelf Bookcase...  383.4656         4
# 9972                        Cameo Buff Policy Envelopes   99.5680         2
# 9989                             Ultra Door Pull Handle   25.2480         3
#
#       Discount    Profit
# 3         0.45 -383.0310
# 4         0.20    2.5164
# 14        0.80 -123.8580
# 15        0.80   -3.8160
# 34        0.20    9.9468
# ...        ...       ...
# 9920      0.80  -35.8176
# 9961      0.20   23.7742
# 9962      0.32  -67.6704
# 9972      0.20   33.6042
# 9989      0.20    4.1028
#
# [1368 rows x 21 columns]

# %% [markdown]
# Полученную таблицу можно сохранить в переменную и продолжить работать с ней как с электронной таблицей:

# %% [markdown]
# Попробуйте сами написать фильтр для поиска товаров, доставляемых в Нью-Йорк вторым классом.

# %% [markdown]
# Фильтр для поиска корпоративных клиентов из штата Канзас, которые покупали бумагу или аксессуары. Сохраните полученные условия и результаты в переменные.

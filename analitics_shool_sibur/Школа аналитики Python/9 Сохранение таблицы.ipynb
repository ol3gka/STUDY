# %% [markdown]
# # Сохранение результатов работы в Excel
#
# После окончания работы с таблицей, зачастую, результаты нужно сохранить обратно в файл excel. Для сохранения используется функция `to_excel` таблицы, которая принимает один обязательный параметр, название таблицы (или путь к таблице, если ее надо сохранить в другой папке).
#
# **Pandas перезаписывает файл Excel!** Не давайте ей то же название, что было у изначальной таблицы во избежание потери данных.

# %% [markdown]
# Перед тем, как сохранять таблицу, ее нужно сначала открыть. Сделаем в ней какие-нибудь изменения.
#
# В качестве упражнения проделайте следующие действия:
#
# * Импортируйте из библиотеки pandas метод read_excel
# * Откройте таблицу `Superstore.xlsx` на листе `Orders`
# * Выберите из данных только продажи телефонов, которые были совершены в Западный регионе США
# * Сохраните результат под именем `phones_west`

# %%
# Проделайте операции из задания выше

# %%
phones_west.to_excel('Продажи телефонов на Западе.xlsx')

# %% [markdown]
# В результате получится простая таблица Excel почти без форматирования:
# ![image.png](attachment:image.png)
#
# У `to_excel` есть несколько дополнительных параметров:
# * `index=False` – убрать колонку с номерами строк исходной таблицы
# * `header=False` – убрать заголовки таблицы

# %%
phones_west.to_excel('Продажи телефонов на Западе.xlsx', index=False)
